# %%
# %matplotlib notebook 

#manipular el plot

import numpy as np 
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d

#: metodo de ambito , todo lo indexado pertenece a la funcion que se cree 
# atributos, variables que se guardan en la memoria del computador 
# set usar atributos fuera de la clase 
# get obtener atributos fuera de la clase
# :: scale, salto en una lista

# %%
A=1
B=2
omega= 2*np.pi/10
N=100

# %%
t= np.linspace(0,10,N)
t
r=np.zeros((N,3))

# %%
r[:,0]=A*np.cos(omega*t)
r[:,1]=A*np.sin(omega*t)
r[:,2]=B*t

# %%
fig= plt.figure(figsize=(5,5))
ax = fig.add_subplot(111,projection="3d")
ax.scatter(r[:,0],r[:,1],r[:,2],color='k', marker='o',s=50)
ax.view_init()
# Out:
# <img src="data:image/png;base64,..." width="500">

# %%
#Graficar en polares
theta=np.linspace(0,2*np.pi,100)
r=2*theta
r= 0.1/(1+0.1*np.cos(theta))
fig= plt.figure(figsize=(5,5))
ax = fig.add_subplot(111,projection="polar")
ax.scatter(theta,r)
# Out:
# <img src="data:image/png;base64,..." width="500">

# %%
#campos vectoriales
n=8
#mallado
x=np.linspace(0,1,n)
y=np.linspace(0,1,n)
X,Y = np.meshgrid(x,y)
#meshgrid 
fig= plt.figure(figsize=(5,5))
ax = fig.add_subplot(111)
ax.scatter(X,Y)
ax1 = fig.add_subplot(122)
#guardar 
Ex= np.zeros((n,n))
Ey=np.zeros((n,n))
for i in range(n):
    for j in range(n):
        Ex[i,j]=1
        Ey[i,j]=-2.

for i in range(n):
    for j in range(n):
        ax.quiver(x[i],y[j],Ex[i,j],Ey[i,j])
        
ax1.streamplot(X,Y,Ex.T,Ey.T,density=2)
# Out:
# <img src="data:image/png;base64,..." width="500">

# %%
r0=np.array([0.5,0.4])
r2=np.array([])
X,Y = np.meshgrid(x,y)
Ex=X-r0[0]
Ey=Y-r0[1]

def GetE(r,r0,q=1,c=0):
    d= (r[0]-r0[0])**2 + (r[1]-r[1])**2
    return q*r[c]/d**(3/2)

Ex= np.zeros((n,n))
Ey=np.zeros((n,n))
for i in range(n):
    for j in range(n):
        Ex[i,j]=GetE([x[i],y[j],r0,1,0])
        Ey[i,j]=GetE([x[i],y[j],r0,1,1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\J93A3~1.PAB\AppData\Local\Temp/ipykernel_12828/927391822.py in <module>
#      13 for i in range(n):
#      14     for j in range(n):
# ---> 15         Ex[i,j]=GetE([x[i],y[j],r0,1,0])
#      16         Ey[i,j]=GetE([x[i],y[j],r0,1,1])
#
# TypeError: GetE() missing 1 required positional argument: 'r0'
